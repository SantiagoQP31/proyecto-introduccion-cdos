# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Cargar el archivo Excel, pones tu path
path = "C:\\Users\\Isabella Arrieta G\\OneDrive - Universidad Tecnológica de Bolívar\\Documentos\\Tareas\\UTB\\Semestre 8\\Machine Learning\\proyecto-introduccion-cdos\\data\\whr25_data_figure_2.1.xlsx"
df=pd.read_excel(path)
df
# Out:
#       Year  Rank Country name  Ladder score  upperwhisker  lowerwhisker  \
# 0     2024     1      Finland         7.736         7.810         7.662
# 1     2023   143  Afghanistan         1.721         1.775         1.667
# 2     2022   137  Afghanistan         1.859         1.923         1.795
# 3     2021   146  Afghanistan         2.404         2.469         2.339
# 4     2020   150  Afghanistan         2.523         2.596         2.449
# ...    ...   ...          ...           ...           ...           ...
# 1964  2016   138     Zimbabwe         3.875           NaN           NaN
# 1965  2015   131     Zimbabwe         4.193           NaN           NaN
# 1966  2014   115     Zimbabwe         4.610           NaN           NaN
# 1967  2012   103     Zimbabwe         4.827           NaN           NaN
# 1968  2011   142     Zimbabwe         3.978           NaN           NaN
#
#       Explained by: Log GDP per capita  Explained by: Social support  \
# ...

# %%
df_2024 = df[df['Year']==2024]
df_2024
# Out:
#       Year  Rank  Country name  Ladder score  upperwhisker  lowerwhisker  \
# 0     2024     1       Finland         7.736         7.810         7.662
# 13    2024     2       Denmark         7.521         7.611         7.431
# 26    2024     3       Iceland         7.515         7.606         7.425
# 45    2024     4        Sweden         7.345         7.427         7.262
# 58    2024     5   Netherlands         7.306         7.372         7.240
# ...    ...   ...           ...           ...           ...           ...
# 1905  2024   143      Zimbabwe         3.396         3.509         3.283
# 1918  2024   144        Malawi         3.260         3.390         3.130
# 1931  2024   145       Lebanon         3.188         3.277         3.098
# 1943  2024   146  Sierra Leone         2.998         3.102         2.894
# 1956  2024   147   Afghanistan         1.364         1.427         1.301
#
#       Explained by: Log GDP per capita  Explained by: Social support  \
# ...

# %%
df_2024 = df[df['Year']==2024].sort_values(by="Ladder score", ascending=False)
df_2024
# Out:
#       Year  Rank  Country name  Ladder score  upperwhisker  lowerwhisker  \
# 0     2024     1       Finland         7.736         7.810         7.662
# 13    2024     2       Denmark         7.521         7.611         7.431
# 26    2024     3       Iceland         7.515         7.606         7.425
# 45    2024     4        Sweden         7.345         7.427         7.262
# 58    2024     5   Netherlands         7.306         7.372         7.240
# ...    ...   ...           ...           ...           ...           ...
# 1905  2024   143      Zimbabwe         3.396         3.509         3.283
# 1918  2024   144        Malawi         3.260         3.390         3.130
# 1931  2024   145       Lebanon         3.188         3.277         3.098
# 1943  2024   146  Sierra Leone         2.998         3.102         2.894
# 1956  2024   147   Afghanistan         1.364         1.427         1.301
#
#       Explained by: Log GDP per capita  Explained by: Social support  \
# ...

# %%
df_2024[df_2024["Country name"]=="Colombia"]
# Out:
#      Year  Rank Country name  Ladder score  upperwhisker  lowerwhisker  \
# 800  2024    61     Colombia         6.004         6.112         5.897
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 800                              1.38                         1.513
#
#      Explained by: Healthy life expectancy  \
# 800                                  0.587
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 800                                       0.777                     0.039
#
#      Explained by: Perceptions of corruption  Dystopia + residual
# 800                                    0.051                1.658

# %%
df_2024[(df_2024["Rank"]>=60)&(df_2024["Rank"]<=62)]
# Out:
#      Year  Rank Country name  Ladder score  upperwhisker  lowerwhisker  \
# 787  2024    60     Portugal         6.013         6.118         5.907
# 800  2024    61     Colombia         6.004         6.112         5.897
# 813  2024    62      Ecuador         5.965         6.083         5.848
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 787                             1.646                         1.560
# 800                             1.380                         1.513
# 813                             1.299                         1.320
#
#      Explained by: Healthy life expectancy  \
# 787                                  0.822
# 800                                  0.587
# 813                                  0.702
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 787                                       0.879                     0.040
# 800                                       0.777                     0.039
# ...

# %%
df_colombia = df[df["Country name"]=="Colombia"].sort_values(by="Year")
plt.figure(figsize=(10, 3))
plt.plot(df_colombia['Year'], df_colombia['Ladder score'], marker='.', color="purple")
plt.title('Felicidad de Colombia a lo largo de los años')
plt.xlabel('Año')
plt.ylabel('Ladder Score')
plt.axvspan(2019,2022, color='yellow', alpha=0.5)
plt.grid(True)
plt.tight_layout()
plt.savefig('happiness_through_years_colombia.png')
plt.show()

# %%
happiest_countries = df_2024[df_2024['Country name'].isin(['Finland', 'Denmark', 'Iceland'])]

# Select the 'Explained by:' columns and 'Country name'
happiness_components = [
    'Country name',
    'Explained by: Log GDP per capita',
    'Explained by: Social support',
    'Explained by: Healthy life expectancy',
    'Explained by: Freedom to make life choices',
    'Explained by: Generosity',
    'Explained by: Perceptions of corruption',
    'Dystopia + residual'
]

df_components = happiest_countries[happiness_components].set_index('Country name')

# Plotting the stacked bar chart horizontally
ax = df_components.plot(kind='barh', stacked=True, figsize=(12, 7), colormap='tab10')
plt.title('Componentes de Felicidad para Finlandia, Dinamarca e Islandia (2024)')
plt.xlabel('Puntuación de Felicidad')
plt.ylabel('País')
plt.xticks(rotation=0)
plt.legend(title='Componente', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
happiest_countries = df_2024[df_2024['Country name'].isin(['Portugal', 'Colombia', 'Ecuador'])]

# Select the 'Explained by:' columns and 'Country name'
happiness_components = [
    'Country name',
    'Explained by: Log GDP per capita',
    'Explained by: Social support',
    'Explained by: Healthy life expectancy',
    'Explained by: Freedom to make life choices',
    'Explained by: Generosity',
    'Explained by: Perceptions of corruption',
    'Dystopia + residual'
]

df_components = happiest_countries[happiness_components].set_index('Country name')

# Plotting the stacked bar chart horizontally
ax = df_components.plot(kind='barh', stacked=True, figsize=(12, 7), colormap='tab10')
plt.title('Componentes de Felicidad para Finlandia, Dinamarca e Islandia (2024)')
plt.xlabel('Puntuación de Felicidad')
plt.ylabel('País')
plt.xticks(rotation=0)
plt.legend(title='Componente', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Task
# Create a stacked bar chart showing the components of happiness for Latin American countries using the `df_2024` DataFrame, with 'Country name' as the index and columns for 'Explained by: Log GDP per capita', 'Explained by: Social support', 'Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices', 'Explained by: Generosity', 'Explained by: Perceptions of corruption', and 'Dystopia + residual'.

# %% [markdown]
# ## Identify Latin American Countries
#
# ### Subtask:
# Create a list of countries that are typically considered part of Latin America.

# %% [markdown]
# **Reasoning**:
# I need to create a Python list named `latin_american_countries` containing country names that match the 'Country name' column in the `df_2024` DataFrame.

# %%
latin_american_countries = [
    'Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Costa Rica', 'Cuba',
    'Dominican Republic', 'Ecuador', 'El Salvador', 'Guatemala', 'Honduras',
    'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'Uruguay', 'Venezuela'
]

print("List of Latin American countries created.")
# Out:
# List of Latin American countries created.

# %% [markdown]
# ## Filter DataFrame for LATAM
#
# ### Subtask:
# Filter the `df_2024` DataFrame to select only the rows corresponding to the identified Latin American countries. This will create a new DataFrame containing data for LATAM countries in 2024.

# %% [markdown]
# **Reasoning**:
# To filter the `df_2024` DataFrame for Latin American countries, I will use the `isin()` method on the 'Country name' column with the `latin_american_countries` list and store the result in a new DataFrame named `df_latam_2024`. Then, I will display the new DataFrame to verify the filtering.

# %%
df_latam_2024 = df_2024[df_2024['Country name'].isin(latin_american_countries)]
df_latam_2024
# Out:
#       Year  Rank        Country name  Ladder score  upperwhisker  \
# 71    2024     6          Costa Rica         7.274         7.361
# 122   2024    10              Mexico         6.979         7.068
# 377   2024    28             Uruguay         6.661         6.743
# 484   2024    36              Brazil         6.494         6.593
# 495   2024    37         El Salvador         6.492         6.619
# 547   2024    41              Panama         6.407         6.531
# 550   2024    42           Argentina         6.397         6.492
# 576   2024    44           Guatemala         6.362         6.503
# 589   2024    45               Chile         6.361         6.449
# 608   2024    47           Nicaragua         6.330         6.475
# 709   2024    54            Paraguay         6.172         6.279
# 800   2024    61            Colombia         6.004         6.112
# 813   2024    62             Ecuador         5.965         6.083
# ...

# %% [markdown]
# ## Generate Stacked Bar Chart for LATAM
#
# ### Subtask:
# Create a horizontal stacked bar chart using the filtered Latin American countries data. The chart will display the 'Ladder score' components, similar to the previous plots, with appropriate titles and labels for the LATAM region.

# %% [markdown]
# **Reasoning**:
# To generate the stacked bar chart for Latin American countries, I will select the specified happiness components, set 'Country name' as the index, and then plot the data as a horizontal stacked bar chart with appropriate titles, labels, and legend, as per the instructions.

# %%
happiness_components_latam = [
    'Country name',
    'Explained by: Log GDP per capita',
    'Explained by: Social support',
    'Explained by: Healthy life expectancy',
    'Explained by: Freedom to make life choices',
    'Explained by: Generosity',
    'Explained by: Perceptions of corruption',
    'Dystopia + residual'
]

df_latam_components = df_latam_2024[happiness_components_latam].set_index('Country name')

# Plotting the stacked bar chart horizontally
ax = df_latam_components.plot(kind='barh', stacked=True, figsize=(12, 8), colormap='plasma')
plt.title('Componentes de Felicidad para Países Latinoamericanos (2024)')
plt.xlabel('Puntuación de Felicidad')
plt.ylabel('País')
plt.xticks(rotation=0)
plt.legend(title='Componente', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig('stacked_bar_chart_latam.png')
plt.show()

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Review the generated stacked bar chart for Latin American countries and provide any further insights or analysis.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The task was to review the generated stacked bar chart for Latin American countries and provide any further insights or analysis.
# While the chart image is not directly provided in this summary, the process describes its creation, enabling the following insights: The stacked bar chart allows for a visual comparison of the contribution of various factors (like GDP, social support, life expectancy, freedom, generosity, and perception of corruption) to the overall happiness score (Ladder score) for each Latin American country. It highlights which factors are stronger or weaker drivers of happiness in different countries within the region for 2024, as well as the 'Dystopia + residual' component.
#
# ### Data Analysis Key Findings
# *   A specific list of 19 Latin American countries was identified for analysis.
# *   The `df_2024` DataFrame was successfully filtered, resulting in `df_latam_2024`, which contains happiness data for 18 Latin American countries for the year 2024.
# *   A horizontal stacked bar chart was generated to visualize the individual components contributing to the overall happiness score for these 18 Latin American countries. The components include 'Explained by: Log GDP per capita', 'Explained by: Social support', 'Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices', 'Explained by: Generosity', 'Explained by: Perceptions of corruption', and 'Dystopia + residual'.
#
# ### Insights or Next Steps
# *   Analyze the generated chart to identify which components contribute most significantly to happiness in different Latin American countries and pinpoint countries with particularly high or low contributions from specific factors.
# *   Compare the contribution of 'Perceptions of corruption' across countries to understand its impact on overall happiness in the region.

# %% [markdown]
# ## Gráficos para el Storytelling

# %%
import matplotlib.cm as cm # Importamos cm para los colormaps

# Ensure Year is integer
df['Year'] = df['Year'].astype(int)

# Factors list
factors = [
    'Explained by: Log GDP per capita',
    'Explained by: Social support',
    'Explained by: Healthy life expectancy',
    'Explained by: Freedom to make life choices',
    'Explained by: Generosity',
    'Explained by: Perceptions of corruption'
]
factor_labels = ['PIB', 'Soporte Social', 'Expectativa de Vida', 'Libertad', 'Generosidad', 'Corrupción']

# ==========================================
# Gráfico 1: Scatter Plot - Riqueza vs Felicidad (2024)
# ==========================================
df_2024 = df[df['Year'] == 2024].copy()
latam_countries = [
    'Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Costa Rica',
    'Dominican Republic', 'Ecuador', 'El Salvador', 'Guatemala', 'Honduras',
    'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 'Peru', 'Uruguay', 'Venezuela'
]

plt.figure(figsize=(10, 6))
# All other countries
df_others = df_2024[~df_2024['Country name'].isin(latam_countries)]
plt.scatter(df_others['Explained by: Log GDP per capita'], df_others['Ladder score'],
            color='lightgrey', alpha=0.6, label='Resto del Mundo')

# Latam
df_latam = df_2024[df_2024['Country name'].isin(latam_countries) & (df_2024['Country name'] != 'Colombia')]
plt.scatter(df_latam['Explained by: Log GDP per capita'], df_latam['Ladder score'],
            color='skyblue', alpha=0.9, label='Latinoamérica')

# Colombia
df_col_2024 = df_2024[df_2024['Country name'] == 'Colombia']
if not df_col_2024.empty:
    plt.scatter(df_col_2024['Explained by: Log GDP per capita'], df_col_2024['Ladder score'],
                color='gold', edgecolor='black', s=150, label='Colombia', zorder=5)

plt.title('Riqueza vs Felicidad: ¿Dónde está Colombia en el Mundo? (2024)', fontsize=14, fontweight='bold')
plt.xlabel('Puntaje aportado por PIB per Cápita', fontsize=12)
plt.ylabel('Puntaje de Felicidad (Ladder Score)', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.savefig('scatter_wealth_vs_happiness.png', dpi=300)
plt.close()

# ==========================================
# Gráfico 2: Stacked Area Chart - Composición histórica (Colombia)
# ==========================================
# Filtrar Colombia y Años >= 2018
df_col_all = df[(df['Country name'] == 'Colombia') & (df['Year'] >= 2018)].sort_values('Year').copy()
# Fill NaN if any
df_col_all = df_col_all.fillna(0)

# 1. Determinar el número de capas (factores + Dystopia + residual)
num_layers = len(factors) + 1 
# 2. Generar una lista de colores usando el colormap 'plasma'
# np.linspace(0, 0.9, num_layers) crea un array de números espaciados uniformemente
# entre 0 y 0.9 (para evitar los colores más claros al final del colormap si no los quieres).
colors = cm.plasma(np.linspace(0, 0.9, num_layers))
# ---------------------------------------

plt.figure(figsize=(12, 7))

plt.stackplot(df_col_all['Year'],
              df_col_all[factors[0]], df_col_all[factors[1]], df_col_all[factors[2]],
              df_col_all[factors[3]], df_col_all[factors[4]], df_col_all[factors[5]],
              df_col_all['Dystopia + residual'],
              labels=factor_labels + ['Distopía + Residual'],
              colors=colors, # ¡Aquí pasamos la lista de colores generada!
              alpha=0.85)

plt.title('De qué está hecha la felicidad en Colombia (2018 en adelante)', fontsize=14, fontweight='bold')
plt.xlabel('Año', fontsize=12)
plt.ylabel('Composición del Puntaje de Felicidad', fontsize=12)
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1), borderaxespad=0.)

# Aseguramos que los años en el eje X sean enteros
plt.xticks(df_col_all['Year'].astype(int))

plt.margins(x=0)
plt.tight_layout()
plt.savefig('colombia_happiness_composition_area.png', dpi=300)
plt.show() # Para mostrar el gráfico si estás en un entorno interactivo como Jupyter
plt.close()

# ==========================================
# Gráfico 3: Bar Chart Comparativo - Colombia vs Finlandia (2024)
# ==========================================
df_finland_2024 = df_2024[df_2024['Country name'] == 'Finland']

if not df_col_2024.empty and not df_finland_2024.empty:
    col_values = df_col_2024[factors].values[0]
    fin_values = df_finland_2024[factors].values[0]

    x = np.arange(len(factor_labels))
    width = 0.35

    plt.figure(figsize=(10, 6))
    plt.barh(x - width/2, col_values, width, label='Colombia', color='gold', edgecolor='black')
    plt.barh(x + width/2, fin_values, width, label='Finlandia (Top 1)', color='cornflowerblue', edgecolor='black')

    plt.title('Colombia vs El País Más Feliz (Finlandia - 2024)', fontsize=14, fontweight='bold')
    plt.xlabel('Puntaje Aportado a la Felicidad', fontsize=12)
    plt.yticks(x, factor_labels)
    plt.legend()
    plt.grid(axis='x', linestyle='--', alpha=0.5)
    plt.gca().invert_yaxis() # Highest factor at top
    plt.tight_layout()
    plt.savefig('colombia_vs_finland_bar.png', dpi=300)
    plt.close()

print("Graphs generated successfully.")
# Out:
# Graphs generated successfully.
